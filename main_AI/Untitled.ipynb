# %%
import warnings
warnings.filterwarnings('ignore')
import ai_main

# %%
ai = ai_main.Main_AI(16,4,verbose=True)
nb_image_classified = ai.run()
# Out:
# ---------------- Step 0 ----------------
#
# AI decided to return card 11
# The prediction for the first card 11 is :
# [{'class': 'orange', 'score': 0.9869999885559082}, {'class': 'lemon', 'score': 0.012000000104308128}, {'class': 'honeycomb', 'score': 0.0}, {'class': 'butternut_squash', 'score': 0.0}, {'class': 'acorn_squash', 'score': 0.0}]
#
# AI decided to return card 3
# The predictions are :
# 3 : [{'class': 'box_turtle', 'score': 0.8949999809265137}, {'class': 'terrapin', 'score': 0.07000000029802322}, {'class': 'mud_turtle', 'score': 0.02800000086426735}, {'class': 'tailed_frog', 'score': 0.0010000000474974513}, {'class': 'leatherback_turtle', 'score': 0.0010000000474974513}]
# 11 : [{'class': 'orange', 'score': 0.9869999885559082}, {'class': 'lemon', 'score': 0.012000000104308128}, {'class': 'honeycomb', 'score': 0.0}, {'class': 'butternut_squash', 'score': 0.0}, {'class': 'acorn_squash', 'score': 0.0}]
#
# 0: unknown - Status.UNKNOWN
# 1: unknown - Status.UNKNOWN
# ...
